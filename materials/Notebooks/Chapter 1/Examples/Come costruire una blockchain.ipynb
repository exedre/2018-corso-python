# %%
import hashlib

hashlib.md5('Emmanuele Somma'.encode('utf-8')).hexdigest()
# Out:
# 'c4131bbebad54fa2639076c1d898e787'

# %% [markdown]
# # Come si fa una blockchain in Python
#
# Una *Blockchain* è un libro mastro digitale in cui le transazioni sono registrate in ordine cronologico e pubblico dotata della caratteristica che una eventuale modifica di una transazione nella catena dei blocchi rende immediatamente invalida ogni successivo blocco.
#
# ![Blockchain](https://cdn-images-1.medium.com/max/2000/1*YrmY7iWMK6xN7vGSPrBYlA.png)

# %% [markdown]
# ## Creazione dell'oggetto "Block"
#
# Contiene un indice, il tempo di creazione, i dati che porta (payload) e l'hash_del blocco precedente

# %%
import hashlib as hasher

class Block:
  def __init__(self, index, timestamp, data, previous_hash):
    self.index = index
    self.timestamp = timestamp
    self.data = data
    self.previous_hash = previous_hash
    self.hash = self.hash_block()
  
  def hash_block(self):
    sha = hasher.sha256()
    sha.update((str(self.index) + 
               str(self.timestamp) + 
               str(self.data) + 
               str(self.previous_hash)).encode())
    return sha.hexdigest()

# %% [markdown]
# ## Creazione del primo blocco (Genesi)

# %%
import datetime as date

def create_genesis_block():
  # Manually construct a block with
  # index zero and arbitrary previous hash
  return Block(0, date.datetime.now(), "Genesis Block", "0")

# %% [markdown]
# # Aggiunta di un nuovo blocco al precedente

# %%
def next_block(last_block):
  this_index = last_block.index + 1
  this_timestamp = date.datetime.now()
  this_data = "Hey! I'm block " + str(this_index)
  this_hash = last_block.hash
  return Block(this_index, this_timestamp, this_data, this_hash)

# %% [markdown]
# # Creazione della Blockchain

# %%
# Create the blockchain and add the genesis block
blockchain = [create_genesis_block()]
previous_block = blockchain[0]

# How many blocks should we add to the chain
# after the genesis block
num_of_blocks_to_add = 20

# Add blocks to the chain
for i in range(0, num_of_blocks_to_add):
  block_to_add = next_block(previous_block)
  blockchain.append(block_to_add)
  previous_block = block_to_add
  # Tell everyone about it!
  print ("Block #{} has been added to the blockchain!".format(block_to_add.index))
  print (" Data:  {}".format(block_to_add.data) )
  print (" Hash:  {}\n  Prev: {}\n".format(block_to_add.hash, block_to_add.previous_hash) )
# Out:
# Block #1 has been added to the blockchain!
#  Data:  Hey! I'm block 1
#  Hash:  71ea5a9b36095617149b54a2abdba47454dc75def2291c9259299c244ecc0619
#   Prev: 66bd01d4dc3a4ced13948c321f3a27617f51cb2e83ea7f53c8826dc247f8214b
#
# Block #2 has been added to the blockchain!
#  Data:  Hey! I'm block 2
#  Hash:  c642b55fcc16ecde27c6c3c627ac3c8346bf3e709f70d9f86c66f12e1ffe8f3c
#   Prev: 71ea5a9b36095617149b54a2abdba47454dc75def2291c9259299c244ecc0619
#
# Block #3 has been added to the blockchain!
#  Data:  Hey! I'm block 3
#  Hash:  be817cc0a9c538f75389914ed08a70620bd696634409dc1d7640d58fedc2f425
#   Prev: c642b55fcc16ecde27c6c3c627ac3c8346bf3e709f70d9f86c66f12e1ffe8f3c
#
# Block #4 has been added to the blockchain!
#  Data:  Hey! I'm block 4
#  Hash:  de8ba49f354b000e9bc45d8b2b5d9fe4135cd9231a45c859b0b569cafcd6d56d
#   Prev: be817cc0a9c538f75389914ed08a70620bd696634409dc1d7640d58fedc2f425
#
# Block #5 has been added to the blockchain!
#  Data:  Hey! I'm block 5
#  Hash:  e0b5ffe5aea01f1adcb10e84aaebf532b0d05778b3b8a587d01512a6a6101e9c
#   Prev: de8ba49f354b000e9bc45d8b2b5d9fe4135cd9231a45c859b0b569cafcd6d56d
#
# Block #6 has been added to the blockchain!
#  Data:  Hey! I'm block 6
#  Hash:  44f13d0b6e9f5f81797d0432ca9a2bddb482fe84947d3ece33ba3177ca1fa57c
#   Prev: e0b5ffe5aea01f1adcb10e84aaebf532b0d05778b3b8a587d01512a6a6101e9c
#
# Block #7 has been added to the blockchain!
#  Data:  Hey! I'm block 7
#  Hash:  4270c8bcaefec0f64e2ffc7dd2527f15e4219081720ede88d1fdff83ef7918b4
#   Prev: 44f13d0b6e9f5f81797d0432ca9a2bddb482fe84947d3ece33ba3177ca1fa57c
#
# Block #8 has been added to the blockchain!
#  Data:  Hey! I'm block 8
#  Hash:  4860522cdf8c2013be38694a826777ae598127d0cc1a6d0a6b948a9fa321599c
#   Prev: 4270c8bcaefec0f64e2ffc7dd2527f15e4219081720ede88d1fdff83ef7918b4
#
# Block #9 has been added to the blockchain!
#  Data:  Hey! I'm block 9
#  Hash:  26833dd3b8f80cb2d90505972b1df5da87ecd9a54ec3da57bbdd312f475d99c2
#   Prev: 4860522cdf8c2013be38694a826777ae598127d0cc1a6d0a6b948a9fa321599c
#
# Block #10 has been added to the blockchain!
#  Data:  Hey! I'm block 10
#  Hash:  c0171fdd1269f249d7dd7b1a8f552f2f107a1eae4d4cf8d0ddf1a580b625e368
#   Prev: 26833dd3b8f80cb2d90505972b1df5da87ecd9a54ec3da57bbdd312f475d99c2
#
# Block #11 has been added to the blockchain!
#  Data:  Hey! I'm block 11
#  Hash:  87a385457c13e9f02138e03f2036661ff29756e2223c5686eb42f8fad5c6d9d9
#   Prev: c0171fdd1269f249d7dd7b1a8f552f2f107a1eae4d4cf8d0ddf1a580b625e368
#
# Block #12 has been added to the blockchain!
#  Data:  Hey! I'm block 12
#  Hash:  b8b56edd774c6e5bb23513e5132cd62585ae132991b2f68ed757af7fa78ee491
#   Prev: 87a385457c13e9f02138e03f2036661ff29756e2223c5686eb42f8fad5c6d9d9
#
# Block #13 has been added to the blockchain!
#  Data:  Hey! I'm block 13
#  Hash:  78211619ec5b57aa353d7abd7379993f9d7276e200721380fcc27fe951f57060
#   Prev: b8b56edd774c6e5bb23513e5132cd62585ae132991b2f68ed757af7fa78ee491
#
# Block #14 has been added to the blockchain!
#  Data:  Hey! I'm block 14
#  Hash:  09bdfd2320d9a92c612dfcb591359da85bed177712e9f5e098619bb1ed043f0b
#   Prev: 78211619ec5b57aa353d7abd7379993f9d7276e200721380fcc27fe951f57060
#
# Block #15 has been added to the blockchain!
#  Data:  Hey! I'm block 15
#  Hash:  f1ff59247446d3f8dd25c70810fd1e185899eb99dd52aa44d6a37cb13c3d57f3
#   Prev: 09bdfd2320d9a92c612dfcb591359da85bed177712e9f5e098619bb1ed043f0b
#
# Block #16 has been added to the blockchain!
#  Data:  Hey! I'm block 16
#  Hash:  2d9b303d87753dbb2731c2b6a8831e438318d0164dccdee0e570c8a42d2f84ec
#   Prev: f1ff59247446d3f8dd25c70810fd1e185899eb99dd52aa44d6a37cb13c3d57f3
#
# Block #17 has been added to the blockchain!
#  Data:  Hey! I'm block 17
#  Hash:  0903ea03de6858ff3da7ae23ca17fcf6b6fa1bf67e45aa195492d81001670e3f
#   Prev: 2d9b303d87753dbb2731c2b6a8831e438318d0164dccdee0e570c8a42d2f84ec
#
# Block #18 has been added to the blockchain!
#  Data:  Hey! I'm block 18
#  Hash:  f3ccd593dbc91ac3cd805879445f7a6b595f967e283f91a1d79726868d0e2289
#   Prev: 0903ea03de6858ff3da7ae23ca17fcf6b6fa1bf67e45aa195492d81001670e3f
#
# Block #19 has been added to the blockchain!
#  Data:  Hey! I'm block 19
#  Hash:  5e3c1175b76c4610efef1e0067de78a31ecea5c88d0acbce7854f9d6239c55e0
#   Prev: f3ccd593dbc91ac3cd805879445f7a6b595f967e283f91a1d79726868d0e2289
#
# Block #20 has been added to the blockchain!
#  Data:  Hey! I'm block 20
#  Hash:  ca498efa5b6dfc1c86fce5ddadc6d58a914ef317b06c92924c66894ab371092c
#   Prev: 5e3c1175b76c4610efef1e0067de78a31ecea5c88d0acbce7854f9d6239c55e0

# %% [markdown]
# # E adesso... una vera blockchain
#
# L'implementazione di questa è focalizzata  esclusivamente nella funzione del registro hash. Non include alcuna funzionalità avanzata come un libro mastro distribuito o un protocollo di consenso tramite proof-of-work. L'idea della della "transazione" è astratta a un concetto più generale di "messaggio" che può contenere qualsiasi tipo di dati.
#
# L'obiettivo del programma è quello di spiegare e chiarire in che modo una blockchain è strutturata. Non è costruito con l'intenzione di replicare una blockchain avanzata come Bitcoin o Ethereum.
#
# È composta da 3 classi. La classe ``Message()``, la classe ``Block()`` e ``Chain()``.
#
# Un messaggio è il contenitore dati di base. È "sigillato" quando viene aggiunto a un blocco e ha 2 hash che lo identificano: l'hash del payload (contenuto) e l'hash del blocco. Ogni messaggio è collegato al messaggio precedente tramite puntatori hash (l'attributo prev_hash). Il metodo di convalida del messaggio garantirà l'integrità di ogni messaggio, ma _non controllerà se i puntatori di hash sono corretti_. Questo è lasciato al metodo di validazione nella classe ``Block()``.
#
# Un blocco può contenere 1,...,n messaggi collegati in sequenza uno dopo l'altro. Quando un blocco viene aggiunto alla catena, viene a sua volta sigillato e convalidato per garantire che i messaggi siano ordinati correttamente e che i puntatori di hash corrispondano. Una volta che il blocco è stato sigillato e sottoposto a hash, viene convalidato controllando l'atteso rispetto all'effettivo.
#
# Una catena può contenere 1,...,m blocchi collegati in sequenza uno dopo l'altro. L'integrità della catena può essere validata in qualsiasi momento chiamando il metodo di convalida, che chiamerà il metodo di convalida di ciascun blocco e genererà un'eccezione InvalidBlockchain.

# %%
import datetime
import hashlib
import time

class Message:
	def __init__(self, data):
		self.hash = None
		self.prev_hash = None
		self.timestamp = time.time()
		self.size = len(data.encode('utf-8'))   # length in bytes
		self.data = data
		self.payload_hash = self._hash_payload()

	def _hash_payload(self):
		return hashlib.sha256(bytearray(str(self.timestamp) + str(self.data), "utf-8")).hexdigest()

	def _hash_message(self):
		return hashlib.sha256(bytearray(str(self.prev_hash) + self.payload_hash, "utf-8")).hexdigest()

	def link(self, message):
		""" Link the message to the previous one via hashes."""
		self.prev_hash = message.hash

	def seal(self):
		""" Get the message hash. """
		self.hash = self._hash_message()

	def validate(self):
		""" Check whether the message is valid or not. """
		if self.payload_hash != self._hash_payload():
			raise InvalidMessage("Invalid payload hash in message: " + str(self))
		if self.hash != self._hash_message():
			raise InvalidMessage("Invalid message hash in message: " + str(self))

	def __repr__(self):
		return 'Message<hash: {}, prev_hash: {}, data: {}>'.format(
			self.hash, self.prev_hash, self.data[:20]
		)

# %% [markdown]
# # Il Block

# %%
class Block:
	def __init__(self, *args):
		self.messages = []
		self.timestamp = None
		self.prev_hash = None
		self.hash = None
		if args:
			for arg in args:
				self.add_message(arg)

	def _hash_block(self):
		return hashlib.sha256(bytearray(str(self.prev_hash) + str(self.timestamp) + self.messages[-1].hash, "utf-8")).hexdigest()

	def add_message(self, message):
		if len(self.messages) > 0:
			message.link(self.messages[-1])
		message.seal()
		message.validate()
		self.messages.append(message)
 
	def link(self, block):
		""" The block hash only incorporates the head message hash
			which then transitively includes all prior hashes.
		"""
		self.prev_hash = block.hash
        
	def seal(self):
		self.timestamp = time.time()
		self.hash = self._hash_block()

	def validate(self):
		""" Validates each message hash, then chain integrity, then the block hash.
			Calls each message's validate() method.
			If a message fails validation, this method captures the exception and 
			throws InvalidBlock since an invalid message invalidates the whole block.
		"""
		for i, msg in enumerate(self.messages):
			try:
				msg.validate()
				if i > 0 and msg.prev_hash != self.messages[i-1].hash:
					raise InvalidBlock("Invalid block: Message #{} has invalid message link in block: {}".format(i, str(self)))
				print("  Message {} is valid".format(msg.data))
			except InvalidMessage as ex:
				raise InvalidBlock("Invalid block: Message #{} failed validation: {}. In block: {}".format(
					i, str(ex), str(self))
				)

	def __repr__(self):
		return 'Block<hash: {}, prev_hash: {}, messages: {}, time: {}>'.format(
			self.hash, self.prev_hash, len(self.messages), self.timestamp
		)

# %% [markdown]
# # Blockchain

# %%
class SimpleChain:
	def __init__(self):
		self.chain = []

	def add_block(self, block):
		""" Add a block if valid."""
		if len(self.chain) > 0:
			block.prev_hash = self.chain[-1].hash
		block.seal()
		block.validate()
		self.chain.append(block)

	def validate(self):
		""" Validates each block, in order.
			An invalid block invalidates the chain.
		"""
		for i, block in enumerate(self.chain):
			try:
				block.validate()
				print("Block {} is valid".format(i))
			except InvalidBlock as exc:
				raise InvalidBlockchain("Invalid blockchain at block number {} caused by: {}".format(i, str(exc)))
		return True

	def __repr__(self):
		return 'SimpleChain<blocks: {}>'.format(len(self.chain))

# %%
class InvalidMessage(Exception):
	def __init__(self,*args,**kwargs):
		Exception.__init__(self,*args,**kwargs)

class InvalidBlock(Exception):
	def __init__(self,*args,**kwargs):
		Exception.__init__(self,*args,**kwargs)

class InvalidBlockchain(Exception):
	def __init__(self,*args,**kwargs):
		Exception.__init__(self,*args,**kwargs)

# %%
import random
chain = SimpleChain()
block = Block()

random.seed(10)
N = 20
for j in range(N):
    for i in range(random.randint(1,5)):
        print(("Hi, I'm message {}-{}".format(j,i)))
        block.add_message(Message("Hi, I'm message {}-{}".format(j,i)))
    chain.add_block(block)
    print(block)
    block = Block()
# Out:
# Hi, I'm message 0-0
# Hi, I'm message 0-1
# Hi, I'm message 0-2
# Hi, I'm message 0-3
# Hi, I'm message 0-4
#   Message Hi, I'm message 0-0 is valid
#   Message Hi, I'm message 0-1 is valid
#   Message Hi, I'm message 0-2 is valid
#   Message Hi, I'm message 0-3 is valid
#   Message Hi, I'm message 0-4 is valid
# Block<hash: fa90c076b170042f02671313461f8a2af2d3f75f297d7adb8fac858fb4eac1df, prev_hash: None, messages: 5, time: 1517852367.6348429>
# Hi, I'm message 1-0
#   Message Hi, I'm message 1-0 is valid
# Block<hash: 294eae947f2b96176d2178c0d755d3ca9408e1979289f85fb41166836e94a9e2, prev_hash: fa90c076b170042f02671313461f8a2af2d3f75f297d7adb8fac858fb4eac1df, messages: 1, time: 1517852367.635819>
# Hi, I'm message 2-0
# Hi, I'm message 2-1
# Hi, I'm message 2-2
# Hi, I'm message 2-3
#   Message Hi, I'm message 2-0 is valid
#   Message Hi, I'm message 2-1 is valid
#   Message Hi, I'm message 2-2 is valid
#   Message Hi, I'm message 2-3 is valid
# Block<hash: ff3f5a82c07db2345c17141b97702f6fb3a41643c4d1cca33606ed769dcf4c18, prev_hash: 294eae947f2b96176d2178c0d755d3ca9408e1979289f85fb41166836e94a9e2, messages: 4, time: 1517852367.636051>
# Hi, I'm message 3-0
# Hi, I'm message 3-1
# Hi, I'm message 3-2
# Hi, I'm message 3-3
#   Message Hi, I'm message 3-0 is valid
#   Message Hi, I'm message 3-1 is valid
#   Message Hi, I'm message 3-2 is valid
#   Message Hi, I'm message 3-3 is valid
# Block<hash: fc051c4fb8e0ad54c4ad0901f9d3e41ffcb8be423be59e63b3dcafe6dfcf6a61, prev_hash: ff3f5a82c07db2345c17141b97702f6fb3a41643c4d1cca33606ed769dcf4c18, messages: 4, time: 1517852367.6363719>
# Hi, I'm message 4-0
# Hi, I'm message 4-1
# Hi, I'm message 4-2
# Hi, I'm message 4-3
# Hi, I'm message 4-4
#   Message Hi, I'm message 4-0 is valid
#   Message Hi, I'm message 4-1 is valid
#   Message Hi, I'm message 4-2 is valid
#   Message Hi, I'm message 4-3 is valid
#   Message Hi, I'm message 4-4 is valid
# Block<hash: 6c5266a24dc36f9ca8e1e25fb0e24376f7ac8b29ed207c5cc16802b88d4fb720, prev_hash: fc051c4fb8e0ad54c4ad0901f9d3e41ffcb8be423be59e63b3dcafe6dfcf6a61, messages: 5, time: 1517852367.6415172>
# Hi, I'm message 5-0
#   Message Hi, I'm message 5-0 is valid
# Block<hash: ab34c198c4dfbb1189665b1c5930f4cb165cb44eecf28b03451d7e3ab82057dc, prev_hash: 6c5266a24dc36f9ca8e1e25fb0e24376f7ac8b29ed207c5cc16802b88d4fb720, messages: 1, time: 1517852367.6417348>
# Hi, I'm message 6-0
# Hi, I'm message 6-1
#   Message Hi, I'm message 6-0 is valid
#   Message Hi, I'm message 6-1 is valid
# Block<hash: f71406abfcef172b8f3b6dd2f9bb3ecaf5b8b2529f07ab792b7931289b2e4cb1, prev_hash: ab34c198c4dfbb1189665b1c5930f4cb165cb44eecf28b03451d7e3ab82057dc, messages: 2, time: 1517852367.641859>
# Hi, I'm message 7-0
# Hi, I'm message 7-1
# Hi, I'm message 7-2
# Hi, I'm message 7-3
#   Message Hi, I'm message 7-0 is valid
#   Message Hi, I'm message 7-1 is valid
#   Message Hi, I'm message 7-2 is valid
#   Message Hi, I'm message 7-3 is valid
# Block<hash: 3850caac6e88831add2d2f1832a3199fa0bdf3f0f71dfbe4bc0a03852912f051, prev_hash: f71406abfcef172b8f3b6dd2f9bb3ecaf5b8b2529f07ab792b7931289b2e4cb1, messages: 4, time: 1517852367.642074>
# Hi, I'm message 8-0
# Hi, I'm message 8-1
# Hi, I'm message 8-2
# Hi, I'm message 8-3
#   Message Hi, I'm message 8-0 is valid
#   Message Hi, I'm message 8-1 is valid
#   Message Hi, I'm message 8-2 is valid
#   Message Hi, I'm message 8-3 is valid
# Block<hash: 597c6c980442e9e19711506012fa6da958598378ba9d2feae5fc6838a211922a, prev_hash: 3850caac6e88831add2d2f1832a3199fa0bdf3f0f71dfbe4bc0a03852912f051, messages: 4, time: 1517852367.642572>
# Hi, I'm message 9-0
# Hi, I'm message 9-1
# Hi, I'm message 9-2
#   Message Hi, I'm message 9-0 is valid
#   Message Hi, I'm message 9-1 is valid
#   Message Hi, I'm message 9-2 is valid
# Block<hash: ecba2ec890c1ef2fe79ffb826edadcca054994dcd4fd88a91ffaac6f1b39e8c8, prev_hash: 597c6c980442e9e19711506012fa6da958598378ba9d2feae5fc6838a211922a, messages: 3, time: 1517852367.642856>
# Hi, I'm message 10-0
# Hi, I'm message 10-1
#   Message Hi, I'm message 10-0 is valid
#   Message Hi, I'm message 10-1 is valid
# Block<hash: bdd5a4dd89d1e3cda6a1da7471b466a604b38e73511acf7ee0c900a0af998955, prev_hash: ecba2ec890c1ef2fe79ffb826edadcca054994dcd4fd88a91ffaac6f1b39e8c8, messages: 2, time: 1517852367.6430259>
# Hi, I'm message 11-0
#   Message Hi, I'm message 11-0 is valid
# Block<hash: f8148193f31cf6b489964dcbf5db3755a4d58951b1b35793207732fc978d40c4, prev_hash: bdd5a4dd89d1e3cda6a1da7471b466a604b38e73511acf7ee0c900a0af998955, messages: 1, time: 1517852367.643132>
# Hi, I'm message 12-0
# Hi, I'm message 12-1
# Hi, I'm message 12-2
# Hi, I'm message 12-3
# Hi, I'm message 12-4
#   Message Hi, I'm message 12-0 is valid
#   Message Hi, I'm message 12-1 is valid
#   Message Hi, I'm message 12-2 is valid
#   Message Hi, I'm message 12-3 is valid
#   Message Hi, I'm message 12-4 is valid
# Block<hash: 5be68f3c128ad38b28917a73f99189653b317a8851cd6e37476a25f707cee46a, prev_hash: f8148193f31cf6b489964dcbf5db3755a4d58951b1b35793207732fc978d40c4, messages: 5, time: 1517852367.6433861>
# Hi, I'm message 13-0
# Hi, I'm message 13-1
# Hi, I'm message 13-2
# Hi, I'm message 13-3
#   Message Hi, I'm message 13-0 is valid
#   Message Hi, I'm message 13-1 is valid
#   Message Hi, I'm message 13-2 is valid
#   Message Hi, I'm message 13-3 is valid
# Block<hash: 438a849a4a4f035693e25066e1f73e785b53e5e1b1c5bd8fae6d954d15b7c469, prev_hash: 5be68f3c128ad38b28917a73f99189653b317a8851cd6e37476a25f707cee46a, messages: 4, time: 1517852367.6436749>
# Hi, I'm message 14-0
# Hi, I'm message 14-1
# Hi, I'm message 14-2
#   Message Hi, I'm message 14-0 is valid
#   Message Hi, I'm message 14-1 is valid
#   Message Hi, I'm message 14-2 is valid
# Block<hash: 7c9c6d02df5b54aa6b4b4dfd3625620621a01918c193ae98f74b28ea096e073f, prev_hash: 438a849a4a4f035693e25066e1f73e785b53e5e1b1c5bd8fae6d954d15b7c469, messages: 3, time: 1517852367.643897>
# Hi, I'm message 15-0
#   Message Hi, I'm message 15-0 is valid
# Block<hash: 0062af39c5c0b60ed04f2d547e5a30510653e00a3a5fbb9128917791997baa80, prev_hash: 7c9c6d02df5b54aa6b4b4dfd3625620621a01918c193ae98f74b28ea096e073f, messages: 1, time: 1517852367.644027>
# Hi, I'm message 16-0
# Hi, I'm message 16-1
#   Message Hi, I'm message 16-0 is valid
#   Message Hi, I'm message 16-1 is valid
# Block<hash: 392290a63a9ffb45483622fff0c883c398f034831e6654d776393ccb284d8c02, prev_hash: 0062af39c5c0b60ed04f2d547e5a30510653e00a3a5fbb9128917791997baa80, messages: 2, time: 1517852367.644147>
# Hi, I'm message 17-0
# Hi, I'm message 17-1
# Hi, I'm message 17-2
#   Message Hi, I'm message 17-0 is valid
#   Message Hi, I'm message 17-1 is valid
#   Message Hi, I'm message 17-2 is valid
# Block<hash: 89490257fe91bd510841297f6a3bb648b245e61200053a692000de2d9a4698df, prev_hash: 392290a63a9ffb45483622fff0c883c398f034831e6654d776393ccb284d8c02, messages: 3, time: 1517852367.644337>
# Hi, I'm message 18-0
#   Message Hi, I'm message 18-0 is valid
# Block<hash: 5ca2cbdd0351d02d8dd3f94ac032c5964b02a5b7cfd0cd96bcb02d153b023bd8, prev_hash: 89490257fe91bd510841297f6a3bb648b245e61200053a692000de2d9a4698df, messages: 1, time: 1517852367.644479>
# Hi, I'm message 19-0
# Hi, I'm message 19-1
# Hi, I'm message 19-2
# Hi, I'm message 19-3
#   Message Hi, I'm message 19-0 is valid
#   Message Hi, I'm message 19-1 is valid
#   Message Hi, I'm message 19-2 is valid
#   Message Hi, I'm message 19-3 is valid
# Block<hash: 9bbf3675399ef5fb2d0b7ce91d168522f0271bf3d838e7079d46096b12d9d022, prev_hash: 5ca2cbdd0351d02d8dd3f94ac032c5964b02a5b7cfd0cd96bcb02d153b023bd8, messages: 4, time: 1517852367.644673>

# %%
for b in chain.chain:
    print(b)
    print("----------------")
# Out:
# Block<hash: fa90c076b170042f02671313461f8a2af2d3f75f297d7adb8fac858fb4eac1df, prev_hash: None, messages: 5, time: 1517852367.6348429>
# ----------------
# Block<hash: 294eae947f2b96176d2178c0d755d3ca9408e1979289f85fb41166836e94a9e2, prev_hash: fa90c076b170042f02671313461f8a2af2d3f75f297d7adb8fac858fb4eac1df, messages: 1, time: 1517852367.635819>
# ----------------
# Block<hash: ff3f5a82c07db2345c17141b97702f6fb3a41643c4d1cca33606ed769dcf4c18, prev_hash: 294eae947f2b96176d2178c0d755d3ca9408e1979289f85fb41166836e94a9e2, messages: 4, time: 1517852367.636051>
# ----------------
# Block<hash: fc051c4fb8e0ad54c4ad0901f9d3e41ffcb8be423be59e63b3dcafe6dfcf6a61, prev_hash: ff3f5a82c07db2345c17141b97702f6fb3a41643c4d1cca33606ed769dcf4c18, messages: 4, time: 1517852367.6363719>
# ----------------
# Block<hash: 6c5266a24dc36f9ca8e1e25fb0e24376f7ac8b29ed207c5cc16802b88d4fb720, prev_hash: fc051c4fb8e0ad54c4ad0901f9d3e41ffcb8be423be59e63b3dcafe6dfcf6a61, messages: 5, time: 1517852367.6415172>
# ----------------
# Block<hash: ab34c198c4dfbb1189665b1c5930f4cb165cb44eecf28b03451d7e3ab82057dc, prev_hash: 6c5266a24dc36f9ca8e1e25fb0e24376f7ac8b29ed207c5cc16802b88d4fb720, messages: 1, time: 1517852367.6417348>
# ----------------
# Block<hash: f71406abfcef172b8f3b6dd2f9bb3ecaf5b8b2529f07ab792b7931289b2e4cb1, prev_hash: ab34c198c4dfbb1189665b1c5930f4cb165cb44eecf28b03451d7e3ab82057dc, messages: 2, time: 1517852367.641859>
# ----------------
# Block<hash: 3850caac6e88831add2d2f1832a3199fa0bdf3f0f71dfbe4bc0a03852912f051, prev_hash: f71406abfcef172b8f3b6dd2f9bb3ecaf5b8b2529f07ab792b7931289b2e4cb1, messages: 4, time: 1517852367.642074>
# ----------------
# Block<hash: 597c6c980442e9e19711506012fa6da958598378ba9d2feae5fc6838a211922a, prev_hash: 3850caac6e88831add2d2f1832a3199fa0bdf3f0f71dfbe4bc0a03852912f051, messages: 4, time: 1517852367.642572>
# ----------------
# Block<hash: ecba2ec890c1ef2fe79ffb826edadcca054994dcd4fd88a91ffaac6f1b39e8c8, prev_hash: 597c6c980442e9e19711506012fa6da958598378ba9d2feae5fc6838a211922a, messages: 3, time: 1517852367.642856>
# ----------------
# Block<hash: bdd5a4dd89d1e3cda6a1da7471b466a604b38e73511acf7ee0c900a0af998955, prev_hash: ecba2ec890c1ef2fe79ffb826edadcca054994dcd4fd88a91ffaac6f1b39e8c8, messages: 2, time: 1517852367.6430259>
# ----------------
# Block<hash: f8148193f31cf6b489964dcbf5db3755a4d58951b1b35793207732fc978d40c4, prev_hash: bdd5a4dd89d1e3cda6a1da7471b466a604b38e73511acf7ee0c900a0af998955, messages: 1, time: 1517852367.643132>
# ----------------
# Block<hash: 5be68f3c128ad38b28917a73f99189653b317a8851cd6e37476a25f707cee46a, prev_hash: f8148193f31cf6b489964dcbf5db3755a4d58951b1b35793207732fc978d40c4, messages: 5, time: 1517852367.6433861>
# ----------------
# Block<hash: 438a849a4a4f035693e25066e1f73e785b53e5e1b1c5bd8fae6d954d15b7c469, prev_hash: 5be68f3c128ad38b28917a73f99189653b317a8851cd6e37476a25f707cee46a, messages: 4, time: 1517852367.6436749>
# ----------------
# Block<hash: 7c9c6d02df5b54aa6b4b4dfd3625620621a01918c193ae98f74b28ea096e073f, prev_hash: 438a849a4a4f035693e25066e1f73e785b53e5e1b1c5bd8fae6d954d15b7c469, messages: 3, time: 1517852367.643897>
# ----------------
# Block<hash: 0062af39c5c0b60ed04f2d547e5a30510653e00a3a5fbb9128917791997baa80, prev_hash: 7c9c6d02df5b54aa6b4b4dfd3625620621a01918c193ae98f74b28ea096e073f, messages: 1, time: 1517852367.644027>
# ----------------
# Block<hash: 392290a63a9ffb45483622fff0c883c398f034831e6654d776393ccb284d8c02, prev_hash: 0062af39c5c0b60ed04f2d547e5a30510653e00a3a5fbb9128917791997baa80, messages: 2, time: 1517852367.644147>
# ----------------
# Block<hash: 89490257fe91bd510841297f6a3bb648b245e61200053a692000de2d9a4698df, prev_hash: 392290a63a9ffb45483622fff0c883c398f034831e6654d776393ccb284d8c02, messages: 3, time: 1517852367.644337>
# ----------------
# Block<hash: 5ca2cbdd0351d02d8dd3f94ac032c5964b02a5b7cfd0cd96bcb02d153b023bd8, prev_hash: 89490257fe91bd510841297f6a3bb648b245e61200053a692000de2d9a4698df, messages: 1, time: 1517852367.644479>
# ----------------
# Block<hash: 9bbf3675399ef5fb2d0b7ce91d168522f0271bf3d838e7079d46096b12d9d022, prev_hash: 5ca2cbdd0351d02d8dd3f94ac032c5964b02a5b7cfd0cd96bcb02d153b023bd8, messages: 4, time: 1517852367.644673>
# ----------------

# %%
if chain.validate(): print("Integrity validated.")
print(len(chain.chain))
# Out:
#   Message Hi, I'm message 0-0 is valid
#   Message Hi, I'm message 0-1 is valid
#   Message Hi, I'm message 0-2 is valid
#   Message Hi, I'm message 0-3 is valid
# Block 0 is valid
#   Message Hi, I'm message 1-0 is valid
#   Message Hi, I'm message 1-1 is valid
#   Message Hi, I'm message 1-2 is valid
#   Message Hi, I'm message 1-3 is valid
#   Message Hi, I'm message 1-4 is valid
# Block 1 is valid
#   Message Hi, I'm message 2-0 is valid
# Block 2 is valid
#   Message Hi, I'm message 3-0 is valid
#   Message Hi, I'm message 3-1 is valid
#   Message Hi, I'm message 3-2 is valid
# Block 3 is valid
#   Message Hi, I'm message 4-0 is valid
# Block 4 is valid
#   Message Hi, I'm message 5-0 is valid
#   Message Hi, I'm message 5-1 is valid
#   Message Hi, I'm message 5-2 is valid
# Block 5 is valid
#   Message Hi, I'm message 6-0 is valid
#   Message Hi, I'm message 6-1 is valid
#   Message Hi, I'm message 6-2 is valid
#   Message Hi, I'm message 6-3 is valid
#   Message Hi, I'm message 6-4 is valid
# Block 6 is valid
#   Message Hi, I'm message 7-0 is valid
# Block 7 is valid
#   Message Hi, I'm message 8-0 is valid
#   Message Hi, I'm message 8-1 is valid
# Block 8 is valid
#   Message Hi, I'm message 9-0 is valid
#   Message Hi, I'm message 9-1 is valid
#   Message Hi, I'm message 9-2 is valid
# Block 9 is valid
#   Message Hi, I'm message 10-0 is valid
# Block 10 is valid
#   Message Hi, I'm message 11-0 is valid
# Block 11 is valid
#   Message Hi, I'm message 12-0 is valid
#   Message Hi, I'm message 12-1 is valid
#   Message Hi, I'm message 12-2 is valid
# Block 12 is valid
#   Message Hi, I'm message 13-0 is valid
#   Message Hi, I'm message 13-1 is valid
#   Message Hi, I'm message 13-2 is valid
# Block 13 is valid
#   Message Hi, I'm message 14-0 is valid
#   Message Hi, I'm message 14-1 is valid
#   Message Hi, I'm message 14-2 is valid
#   Message Hi, I'm message 14-3 is valid
#   Message Hi, I'm message 14-4 is valid
# Block 14 is valid
#   Message Hi, I'm message 15-0 is valid
#   Message Hi, I'm message 15-1 is valid
#   Message Hi, I'm message 15-2 is valid
#   Message Hi, I'm message 15-3 is valid
# Block 15 is valid
#   Message Hi, I'm message 16-0 is valid
#   Message Hi, I'm message 16-1 is valid
#   Message Hi, I'm message 16-2 is valid
# Block 16 is valid
#   Message Hi, I'm message 17-0 is valid
# Block 17 is valid
#   Message Hi, I'm message 18-0 is valid
#   Message Hi, I'm message 18-1 is valid
#   Message Hi, I'm message 18-2 is valid
#   Message Hi, I'm message 18-3 is valid
# Block 18 is valid
#   Message Hi, I'm message 19-0 is valid
#   Message Hi, I'm message 19-1 is valid
#   Message Hi, I'm message 19-2 is valid
# Block 19 is valid
# Integrity validated.
# 20

# %% [markdown]
# # Falsificazione di un messaggio

# %%
print(chain.chain[16])
chain.chain[16].messages[1].data = "Fake News"
# Out:
# Block<hash: 84ee345aa151c97907d3411c212ca39dba81556afc40a099173e8865d48c2771, prev_hash: 39f2a39675106b74da260f3fee5cdbb25db07b28e37496599f00749e27f1601e, messages: 3, time: 1516793975.2110589>

# %%
if chain.validate(): print("Integrity validated.")
# Out:
#   Message Hi, I'm message 0-0 is valid
#   Message Hi, I'm message 0-1 is valid
#   Message Hi, I'm message 0-2 is valid
#   Message Hi, I'm message 0-3 is valid
# Block 0 is valid
#   Message Hi, I'm message 1-0 is valid
#   Message Hi, I'm message 1-1 is valid
#   Message Hi, I'm message 1-2 is valid
#   Message Hi, I'm message 1-3 is valid
#   Message Hi, I'm message 1-4 is valid
# Block 1 is valid
#   Message Hi, I'm message 2-0 is valid
# Block 2 is valid
#   Message Hi, I'm message 3-0 is valid
#   Message Hi, I'm message 3-1 is valid
#   Message Hi, I'm message 3-2 is valid
# Block 3 is valid
#   Message Hi, I'm message 4-0 is valid
# Block 4 is valid
#   Message Hi, I'm message 5-0 is valid
#   Message Hi, I'm message 5-1 is valid
#   Message Hi, I'm message 5-2 is valid
# Block 5 is valid
#   Message Hi, I'm message 6-0 is valid
#   Message Hi, I'm message 6-1 is valid
#   Message Hi, I'm message 6-2 is valid
#   Message Hi, I'm message 6-3 is valid
#   Message Hi, I'm message 6-4 is valid
# Block 6 is valid
#   Message Hi, I'm message 7-0 is valid
# Block 7 is valid
#   Message Hi, I'm message 8-0 is valid
#   Message Hi, I'm message 8-1 is valid
# Block 8 is valid
#   Message Hi, I'm message 9-0 is valid
#   Message Hi, I'm message 9-1 is valid
#   Message Hi, I'm message 9-2 is valid
# Block 9 is valid
#   Message Hi, I'm message 10-0 is valid
# Block 10 is valid
#   Message Hi, I'm message 11-0 is valid
# Block 11 is valid
#   Message Hi, I'm message 12-0 is valid
#   Message Hi, I'm message 12-1 is valid
#   Message Hi, I'm message 12-2 is valid
# Block 12 is valid
#   Message Hi, I'm message 13-0 is valid
#   Message Hi, I'm message 13-1 is valid
#   Message Hi, I'm message 13-2 is valid
# Block 13 is valid
#   Message Hi, I'm message 14-0 is valid
#   Message Hi, I'm message 14-1 is valid
#   Message Hi, I'm message 14-2 is valid
#   Message Hi, I'm message 14-3 is valid
#   Message Hi, I'm message 14-4 is valid
# Block 14 is valid
#   Message Hi, I'm message 15-0 is valid
#   Message Hi, I'm message 15-1 is valid
#   Message Hi, I'm message 15-2 is valid
#   Message Hi, I'm message 15-3 is valid
# Block 15 is valid
# ---------------------------------------------------------------------------
# InvalidMessage                            Traceback (most recent call last)
# <ipython-input-269-5e67c21bdbfe> in validate(self)
#      38                         try:
# ---> 39                                 msg.validate()
#      40                                 if i > 0 and msg.prev_hash != self.messages[i-1].hash:
#
# <ipython-input-231-56948a9b59b6> in validate(self)
#      30                 if self.payload_hash != self._hash_payload():
# ---> 31                         raise InvalidMessage("Invalid payload hash in message: " + str(self))
#      32                 if self.hash != self._hash_message():
#
# InvalidMessage: Invalid payload hash in message: Message<hash: 56f559b54689336f754695273f597b50797733480267ad9e24b3248bf4f499d0, prev_hash: None, data: Fake News>
#
# During handling of the above exception, another exception occurred:
#
# InvalidBlock                              Traceback (most recent call last)
# <ipython-input-270-c62c41c7d2f9> in validate(self)
#      18                         try:
# ---> 19                                 block.validate()
#      20                                 print("Block {} is valid".format(i))
#
# <ipython-input-269-5e67c21bdbfe> in validate(self)
#      44 				raise InvalidBlock("Invalid block: Message #{} failed validation: {}. In block: {}".format(
# ---> 45 					i, str(ex), str(self))
#      46 				)
#
# InvalidBlock: Invalid block: Message #0 failed validation: Invalid payload hash in message: Message<hash: 56f559b54689336f754695273f597b50797733480267ad9e24b3248bf4f499d0, prev_hash: None, data: Fake News>. In block: Block<hash: 84ee345aa151c97907d3411c212ca39dba81556afc40a099173e8865d48c2771, prev_hash: 39f2a39675106b74da260f3fee5cdbb25db07b28e37496599f00749e27f1601e, messages: 3, time: 1516793975.2110589>
#
# During handling of the above exception, another exception occurred:
#
# InvalidBlockchain                         Traceback (most recent call last)
# <ipython-input-278-2e8c5132d926> in <module>()
# ----> 1 if chain.validate(): print("Integrity validated.")
#       2
#
# <ipython-input-270-c62c41c7d2f9> in validate(self)
#      20                                 print("Block {} is valid".format(i))
#      21                         except InvalidBlock as exc:
# ---> 22                                 raise InvalidBlockchain("Invalid blockchain at block number {} caused by: {}".format(i, str(exc)))
#      23                 return True
#      24
#
# InvalidBlockchain: Invalid blockchain at block number 16 caused by: Invalid block: Message #0 failed validation: Invalid payload hash in message: Message<hash: 56f559b54689336f754695273f597b50797733480267ad9e24b3248bf4f499d0, prev_hash: None, data: Fake News>. In block: Block<hash: 84ee345aa151c97907d3411c212ca39dba81556afc40a099173e8865d48c2771, prev_hash: 39f2a39675106b74da260f3fee5cdbb25db07b28e37496599f00749e27f1601e, messages: 3, time: 1516793975.2110589>
